# %%
student={
    "name": "Meghana",
    "age": 22,
    "course": "Computer Science"
    }

# %%
student
# Out:
# {'name': 'Meghana', 'course': 'Computer Science'}

# %%
student.pop("age")
# Out:
# 22
